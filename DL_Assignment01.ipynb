# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data = pd.DataFrame({
    'Feature1': [2.5, 0.5, 2.2, 1.9, 3.1],
    'Feature2': [2.4, 0.7, 2.9, 2.2, 3.0],
    'Feature3': [1.1, 0.3, 1.5, 1.3, 1.9]
})

data
# Out:
#    Feature1  Feature2  Feature3
# 0       2.5       2.4       1.1
# 1       0.5       0.7       0.3
# 2       2.2       2.9       1.5
# 3       1.9       2.2       1.3
# 4       3.1       3.0       1.9

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

scaled_data
# Out:
# array([[ 0.53102066,  0.193687  , -0.22613351],
#        [-1.77776482, -1.86423738, -1.73369023],
#        [ 0.18470284,  0.79895888,  0.52764485],
#        [-0.16161498, -0.04842175,  0.15075567],
#        [ 1.22365631,  0.92001325,  1.28142321]])

# %%
pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_data)

pca_data
# Out:
# array([[ 0.28669338,  0.51276531],
#        [-3.10394334, -0.01980147],
#        [ 0.87478041, -0.31894889],
#        [-0.03384568, -0.20617731],
#        [ 1.97631524,  0.03216236]])

# %%
pca_full = PCA()
pca_full.fit(scaled_data)

plt.figure()
plt.plot(np.cumsum(pca_full.explained_variance_ratio_), marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Scree Plot')
plt.grid()
plt.show()

# %%
plt.figure()
plt.scatter(pca_data[:, 0], pca_data[:, 1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('2D Visualization using PCA')
plt.grid()
plt.show()
