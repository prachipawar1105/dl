# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %%
train_data = train_datagen.flow_from_directory(
    r"C:\Users\prach\OneDrive\Documents\sample\dataset 7\PlantVillage",
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)
# Out:
# Found 33027 images belonging to 16 classes.

# %%
val_data = train_datagen.flow_from_directory(
    r"C:\Users\prach\OneDrive\Documents\sample\dataset 7\PlantVillage",
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 8249 images belonging to 16 classes.

# %%
model = Sequential()

model.add(Conv2D(32,(3,3),activation='relu',input_shape=(128,128,3)))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(train_data.num_classes,activation='softmax'))
# Out:
# c:\Users\prach\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 1033/1033 ━━━━━━━━━━━━━━━━━━━━ 233s 224ms/step - accuracy: 0.5035 - loss: 1.5604 - val_accuracy: 0.2314 - val_loss: 1.8833
# Epoch 2/10
# 1033/1033 ━━━━━━━━━━━━━━━━━━━━ 166s 160ms/step - accuracy: 0.5254 - loss: 1.1903 - val_accuracy: 0.2203 - val_loss: 2.0605
# Epoch 3/10
# 1033/1033 ━━━━━━━━━━━━━━━━━━━━ 151s 146ms/step - accuracy: 0.5369 - loss: 1.0707 - val_accuracy: 0.2008 - val_loss: 2.0949
# Epoch 4/10
# 1033/1033 ━━━━━━━━━━━━━━━━━━━━ 155s 150ms/step - accuracy: 0.5437 - loss: 1.0043 - val_accuracy: 0.1560 - val_loss: 2.8518
# Epoch 5/10
# 1033/1033 ━━━━━━━━━━━━━━━━━━━━ 157s 152ms/step - accuracy: 0.5499 - loss: 0.9449 - val_accuracy: 0.1628 - val_loss: 2.4129
# Epoch 6/10
# 1033/1033 ━━━━━━━━━━━━━━━━━━━━ 161s 156ms/step - accuracy: 0.5560 - loss: 0.9018 - val_accuracy: 0.1714 - val_loss: 3.7604
# Epoch 7/10
# 1033/1033 ━━━━━━━━━━━━━━━━━━━━ 158s 153ms/step - accuracy: 0.5578 - loss: 0.8769 - val_accuracy: 0.1519 - val_loss: 3.0317
# Epoch 8/10
# ...

# %%
loss, accuracy = model.evaluate(val_data)
print("Validation Accuracy:", accuracy)
# Out:
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 0.1679 - loss: 4.1609
# Validation Accuracy: 0.16789914667606354

# %%
from tensorflow.keras.preprocessing import image

img = image.load_img(r"C:\Users\prach\OneDrive\Documents\sample\test_leaf.png", target_size=(128,128))
img_array = image.img_to_array(img)/255
img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)
predicted_class = np.argmax(prediction)

print("Predicted Class:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Predicted Class: 1
